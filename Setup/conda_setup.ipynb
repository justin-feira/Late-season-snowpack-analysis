# %% [markdown]
# ## Conda requirements
#
# Run these four commands successively in your terminal with conda installed
# 1.  conda activate {your environment name}
# 2. conda install -c conda-forge earthengine-api jupyte notebook ipykernel -y
# 3.  conda install -c conda-forge geopandas folium matplotlib seaborn pandas numpy -y
# 4. python -m ipykernel install --user --name {your environment name} --display-name "Python (GEE)"

# %%
import ee

# Authenticate Earth Engine - this will open a browser window for login
try:
    ee.Authenticate()
    print("Authentication successful!")
except Exception as e:
    print(f"Authentication failed: {e}")
    print("Make sure you have a Google Earth Engine account and internet connection.")
# Out:
# Authentication successful!

# %% [markdown]
# ### authenticating
#
# If running in vs code, paste the code recieved from the authentication window in the bar at the top of the screen. This confused me when i first started :(

# %%
# Initialize Earth Engine
try:
    ee.Initialize()
    print("Google Earth Engine initialized successfully!")
    print(f"EE version: {ee.__version__}")
except Exception as e:
    print(f"Initialization failed: {e}")
    print("Run the authentication cell above first.")

# %%
def initialize_gee():
    try:
        ee.Initialize()
        print("Google Earth Engine initialized successfully!")
        print(f"EE version: {ee.__version__}")
        return True
    except Exception as e:
        print(f"Initialization failed: {e}")
        print("Run the authentication cell above first.")
        return False

def setup_gee():
    """Complete GEE setup - imports packages and initializes ee"""
    import ee
    import folium
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    from IPython.display import Image, display
    import json
    
    # Set up matplotlib
    plt.rcParams['figure.figsize'] = (12, 8)
    sns.set_style("whitegrid")
    
    # Initialize GEE
    return initialize_gee()

print("Setup functions created successfully!")
# Out:
# Setup functions created successfully!
